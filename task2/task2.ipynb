# %%
# %ls ../
# Out:
# data.csv   task1/     task2/     test.csv   train.csv

# %%
import pandas as pd
train_data = pd.read_csv('../train.csv')
test_data =pd.read_csv('../test.csv')

# %%
train_data.head()
# Out:
#    low_volume_percent  middle_volume_percent  \
# 0                0.00                   1.00
# 1                0.00                   1.00
# 2                0.01                   0.53
# 3                0.02                   0.67
# 4                0.02                   0.88
#
#    take_amount_in_later_12_month_highest  trans_amount_increase_rate_lately  \
# 0                                   1000                               0.93
# 1                                      0                               1.49
# 2                                  10000                               0.15
# 3                                    400                              17.95
# 4                                   3000                               1.44
#
#    trans_activity_month  trans_activity_day  transd_mcc  \
# 0                  0.88               0.153        11.0
# 1                  0.67               0.230        13.0
# 2                  1.00               0.330        14.0
# 3                  0.82               0.288        15.0
# 4                  0.97               0.541        18.0
#
#    trans_days_interval_filter  trans_days_interval  regional_mobility  ...  \
# 0                        55.0                 48.0                3.0  ...
# 1                        28.0                 24.0                3.0  ...
# 2                        30.0                 15.0                2.0  ...
# 3                        21.0                 20.0                2.0  ...
# 4                        11.0                 14.0                3.0  ...
#
#    loans_max_limit  loans_avg_limit  consfin_credit_limit  \
# 0           2800.0           1700.0               18600.0
# 1           3300.0           1860.0                8400.0
# 2           5100.0           2500.0               17500.0
# 3           3600.0           1700.0                8000.0
# 4           2400.0           1850.0                7800.0
#
#    consfin_credibility  consfin_org_count_current  consfin_product_count  \
# 0                 80.0                        4.0                    4.0
# 1                 85.0                        2.0                    2.0
# 2                 79.0                        7.0                    8.0
# 3                 80.0                        5.0                    6.0
# 4                 78.0                        7.0                    8.0
#
#    consfin_max_limit  consfin_avg_limit  latest_query_day  loans_latest_day
# 0            20400.0            16050.0               2.0              46.0
# 1             8400.0             8400.0              23.0               2.0
# 2            29100.0            12428.0               4.0              12.0
# 3            40800.0            12480.0              13.0              13.0
# 4            13800.0             6228.0              12.0              59.0
#
# [5 rows x 85 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3118 entries, 0 to 3117
# Data columns (total 85 columns):
# low_volume_percent                            3118 non-null float64
# middle_volume_percent                         3118 non-null float64
# take_amount_in_later_12_month_highest         3118 non-null int64
# trans_amount_increase_rate_lately             3118 non-null float64
# trans_activity_month                          3118 non-null float64
# trans_activity_day                            3118 non-null float64
# transd_mcc                                    3118 non-null float64
# trans_days_interval_filter                    3118 non-null float64
# trans_days_interval                           3118 non-null float64
# regional_mobility                             3118 non-null float64
# repayment_capability                          3118 non-null int64
# is_high_user                                  3118 non-null int64
# number_of_trans_from_2011                     3118 non-null float64
# first_transaction_time                        3118 non-null float64
# historical_trans_amount                       3118 non-null int64
# historical_trans_day                          3118 non-null float64
# rank_trad_1_month                             3118 non-null float64
# trans_amount_3_month                          3118 non-null int64
# avg_consume_less_12_valid_month               3118 non-null float64
# abs                                           3118 non-null int64
# top_trans_count_last_1_month                  3118 non-null float64
# avg_price_last_12_month                       3118 non-null int64
# avg_price_top_last_12_valid_month             3118 non-null float64
# reg_preference_for_trad                       3118 non-null int64
# trans_top_time_last_1_month                   3118 non-null float64
# trans_top_time_last_6_month                   3118 non-null float64
# consume_top_time_last_1_month                 3118 non-null float64
# consume_top_time_last_6_month                 3118 non-null float64
# cross_consume_count_last_1_month              3118 non-null float64
# trans_fail_top_count_enum_last_1_month        3118 non-null float64
# trans_fail_top_count_enum_last_6_month        3118 non-null float64
# trans_fail_top_count_enum_last_12_month       3118 non-null float64
# consume_mini_time_last_1_month                3118 non-null float64
# max_cumulative_consume_later_1_month          3118 non-null int64
# max_consume_count_later_6_month               3118 non-null float64
# railway_consume_count_last_12_month           3118 non-null float64
# pawns_auctions_trusts_consume_last_1_month    3118 non-null int64
# pawns_auctions_trusts_consume_last_6_month    3118 non-null int64
# jewelry_consume_count_last_6_month            3118 non-null float64
# status                                        3118 non-null int64
# source                                        3118 non-null object
# first_transaction_day                         3118 non-null float64
# trans_day_last_12_month                       3118 non-null float64
# id_name                                       3118 non-null object
# apply_score                                   3118 non-null float64
# apply_credibility                             3118 non-null float64
# query_org_count                               3118 non-null float64
# query_finance_count                           3118 non-null float64
# query_cash_count                              3118 non-null float64
# query_sum_count                               3118 non-null float64
# latest_query_time                             3096 non-null object
# latest_one_month_apply                        3118 non-null float64
# latest_three_month_apply                      3118 non-null float64
# latest_six_month_apply                        3118 non-null float64
# loans_score                                   3118 non-null float64
# loans_credibility_behavior                    3118 non-null float64
# loans_count                                   3118 non-null float64
# loans_settle_count                            3118 non-null float64
# loans_overdue_count                           3118 non-null float64
# loans_org_count_behavior                      3118 non-null float64
# consfin_org_count_behavior                    3118 non-null float64
# loans_cash_count                              3118 non-null float64
# latest_one_month_loan                         3118 non-null float64
# latest_three_month_loan                       3118 non-null float64
# latest_six_month_loan                         3118 non-null float64
# history_suc_fee                               3118 non-null float64
# history_fail_fee                              3118 non-null float64
# latest_one_month_suc                          3118 non-null float64
# latest_one_month_fail                         3118 non-null float64
# loans_long_time                               3118 non-null float64
# loans_latest_time                             3118 non-null object
# loans_credit_limit                            3118 non-null float64
# loans_credibility_limit                       3118 non-null float64
# loans_org_count_current                       3118 non-null float64
# loans_product_count                           3118 non-null float64
# loans_max_limit                               3118 non-null float64
# loans_avg_limit                               3118 non-null float64
# consfin_credit_limit                          3118 non-null float64
# consfin_credibility                           3118 non-null float64
# consfin_org_count_current                     3118 non-null float64
# consfin_product_count                         3118 non-null float64
# consfin_max_limit                             3118 non-null float64
# consfin_avg_limit                             3118 non-null float64
# latest_query_day                              3118 non-null float64
# loans_latest_day                              3118 non-null float64
# dtypes: float64(69), int64(12), object(4)
# memory usage: 2.0+ MB

# %%
y = train_data['status']
x = train_data.drop(columns=['status'],axis=1)

# %%
IV值用途：主要用于特征选择，如果想要对变量的预测能力进行排序的化，可以按IV值从高到低进行筛选即可
1. 在机器学习的二分类问题中，IV值（Information Value）主要用来对输入变量进行编码和预测能力的评估!
    特征的IV值的大小即表示该变量的预测能力的强弱
   
2. IV的取值范围是[0,正无穷]，如果当前分组中只包含响应客户或者响应客户时，IV=正无穷，量化指标含义如下：
    小于 0.02：useless for prediction
    0.02 to 0.1：Weak predictor
    0.1 to 0.3： Medium predictor
    0.3 to 0.5：Strong predictor 
    大于 0.5 Suspicious or too good to be true
    
具体查看：https://www.jianshu.com/p/cc4724a373f8

# %%
import math
from scipy import stats
from sklearn.utils.multiclass import type_of_target

#首先需要计算WOE
def calcWOE(x,y,):
    event
